# %%
import pandas as pd
import numpy as np

diretorio = 'GRF_metadata.csv'
ler = pd.read_csv(diretorio)
# Out:
#    DATASET_ID  SUBJECT_ID  SESSION_ID CLASS_LABEL CLASS_LABEL_DETAILED  SEX  \
# 0           1           1           1          HC                   HC  1.0
# 1           1           1           2          HC                   HC  1.0
# 2           1           1           3          HC                   HC  1.0
# 3           1           1           4          HC                   HC  1.0
# 4           1           1           5          HC                   HC  1.0
#
#     AGE  HEIGHT  BODY_WEIGHT  BODY_MASS  ...  AFFECTED_SIDE  SHOD_CONDITION  \
# 0  24.0   184.0        740.1       75.4  ...            NaN               0
# 1  24.0   184.0        735.5       75.0  ...            NaN               0
# 2  24.0   184.0        725.6       74.0  ...            NaN               0
# 3  24.0   184.0        724.3       73.8  ...            NaN               0
# 4  24.0   184.0        727.3       74.1  ...            NaN               0
#
# ...

# %%
ler.head()
# Out:
#    DATASET_ID  SUBJECT_ID  SESSION_ID CLASS_LABEL CLASS_LABEL_DETAILED  SEX  \
# 0           1           1           1          HC                   HC  1.0
# 1           1           1           2          HC                   HC  1.0
# 2           1           1           3          HC                   HC  1.0
# 3           1           1           4          HC                   HC  1.0
# 4           1           1           5          HC                   HC  1.0
#
#     AGE  HEIGHT  BODY_WEIGHT  BODY_MASS  ...  AFFECTED_SIDE  SHOD_CONDITION  \
# 0  24.0   184.0        740.1       75.4  ...            NaN               0
# 1  24.0   184.0        735.5       75.0  ...            NaN               0
# 2  24.0   184.0        725.6       74.0  ...            NaN               0
# 3  24.0   184.0        724.3       73.8  ...            NaN               0
# 4  24.0   184.0        727.3       74.1  ...            NaN               0
#
# ...

# %%
ler.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 661 entries, 0 to 660
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DATASET_ID            661 non-null    int64
#  1   SUBJECT_ID            661 non-null    int64
#  2   SESSION_ID            661 non-null    int64
#  3   CLASS_LABEL           661 non-null    object
#  4   CLASS_LABEL_DETAILED  661 non-null    object
#  5   SEX                   658 non-null    float64
#  6   AGE                   631 non-null    float64
#  7   HEIGHT                637 non-null    float64
#  8   BODY_WEIGHT           661 non-null    float64
#  9   BODY_MASS             661 non-null    float64
#  10  SHOE_SIZE             210 non-null    float64
#  11  AFFECTED_SIDE         0 non-null      float64
#  12  SHOD_CONDITION        661 non-null    int64
#  13  ORTHOPEDIC_INSOLE     661 non-null    int64
#  14  SPEED                 661 non-null    int64
# ...

# %%
ler.describe(include = 'all')
# Out:
#         DATASET_ID  SUBJECT_ID  SESSION_ID CLASS_LABEL CLASS_LABEL_DETAILED  \
# count   661.000000  661.000000  661.000000         661                  661
# unique         NaN         NaN         NaN           1                    1
# top            NaN         NaN         NaN          HC                   HC
# freq           NaN         NaN         NaN         661                  661
# mean      4.172466  154.691377  331.000000         NaN                  NaN
# std       1.986446  101.998983  190.958547         NaN                  NaN
# min       1.000000    1.000000    1.000000         NaN                  NaN
# 25%       3.000000   53.000000  166.000000         NaN                  NaN
# 50%       4.000000  185.000000  331.000000         NaN                  NaN
# 75%       5.000000  227.000000  496.000000         NaN                  NaN
# max      10.000000  350.000000  661.000000         NaN                  NaN
#
# ...

# %%
ler.isnull()
# Out:
#      DATASET_ID  SUBJECT_ID  SESSION_ID  CLASS_LABEL  CLASS_LABEL_DETAILED  \
# 0         False       False       False        False                 False
# 1         False       False       False        False                 False
# 2         False       False       False        False                 False
# 3         False       False       False        False                 False
# 4         False       False       False        False                 False
# ..          ...         ...         ...          ...                   ...
# 656       False       False       False        False                 False
# 657       False       False       False        False                 False
# 658       False       False       False        False                 False
# 659       False       False       False        False                 False
# 660       False       False       False        False                 False
#
# ...

# %%
ler.isnull().sum()
# Out:
# DATASET_ID                0
# SUBJECT_ID                0
# SESSION_ID                0
# CLASS_LABEL               0
# CLASS_LABEL_DETAILED      0
# SEX                       3
# AGE                      30
# HEIGHT                   24
# BODY_WEIGHT               0
# BODY_MASS                 0
# SHOE_SIZE               451
# AFFECTED_SIDE           661
# SHOD_CONDITION            0
# ORTHOPEDIC_INSOLE         0
# SPEED                     0
# READMISSION               0
# SESSION_TYPE              0
# SESSION_DATE              0
# TRAIN                     0
# TRAIN_BALANCED            0
# TEST                      0
# dtype: int64

# %%
ler.dropna()
# Out:
# Empty DataFrame
# Columns: [DATASET_ID, SUBJECT_ID, SESSION_ID, CLASS_LABEL, CLASS_LABEL_DETAILED, SEX, AGE, HEIGHT, BODY_WEIGHT, BODY_MASS, SHOE_SIZE, AFFECTED_SIDE, SHOD_CONDITION, ORTHOPEDIC_INSOLE, SPEED, READMISSION, SESSION_TYPE, SESSION_DATE, TRAIN, TRAIN_BALANCED, TEST]
# Index: []
#
# [0 rows x 21 columns]

# %%
ler.dropna(axis=1, how='all')
# Out:
#      DATASET_ID  SUBJECT_ID  SESSION_ID CLASS_LABEL CLASS_LABEL_DETAILED  \
# 0             1           1           1          HC                   HC
# 1             1           1           2          HC                   HC
# 2             1           1           3          HC                   HC
# 3             1           1           4          HC                   HC
# 4             1           1           5          HC                   HC
# ..          ...         ...         ...         ...                  ...
# 656           9         346         657          HC                   HC
# 657           9         347         658          HC                   HC
# 658          10         348         659          HC                   HC
# 659          10         349         660          HC                   HC
# 660          10         350         661          HC                   HC
#
#      BODY_WEIGHT  BODY_MASS  SHOD_CONDITION  ORTHOPEDIC_INSOLE  SPEED  \
# ...

# %%
ler.fillna(0)
# Out:
#      DATASET_ID  SUBJECT_ID  SESSION_ID CLASS_LABEL CLASS_LABEL_DETAILED  SEX  \
# 0             1           1           1          HC                   HC  1.0
# 1             1           1           2          HC                   HC  1.0
# 2             1           1           3          HC                   HC  1.0
# 3             1           1           4          HC                   HC  1.0
# 4             1           1           5          HC                   HC  1.0
# ..          ...         ...         ...         ...                  ...  ...
# 656           9         346         657          HC                   HC  0.0
# 657           9         347         658          HC                   HC  1.0
# 658          10         348         659          HC                   HC  0.0
# 659          10         349         660          HC                   HC  0.0
# 660          10         350         661          HC                   HC  0.0
#
# ...

# %%
ler.fillna(value={'SEX':1})
# Out:
#      DATASET_ID  SUBJECT_ID  SESSION_ID CLASS_LABEL CLASS_LABEL_DETAILED  SEX  \
# 0             1           1           1          HC                   HC  1.0
# 1             1           1           2          HC                   HC  1.0
# 2             1           1           3          HC                   HC  1.0
# 3             1           1           4          HC                   HC  1.0
# 4             1           1           5          HC                   HC  1.0
# ..          ...         ...         ...         ...                  ...  ...
# 656           9         346         657          HC                   HC  0.0
# 657           9         347         658          HC                   HC  1.0
# 658          10         348         659          HC                   HC  1.0
# 659          10         349         660          HC                   HC  1.0
# 660          10         350         661          HC                   HC  1.0
#
# ...
